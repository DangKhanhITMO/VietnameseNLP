# %%
#Библиотека для предобработки Вьетнамских текстов
# !pip install underthesea
#Входные данные из wikipedia
# !pip install wikipedia
#импорт библиотека pandas
# !pip install --upgrade pip
# !pip install jupyter
# !pip install pandas
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# ...
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# ...
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# ...
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# ...

# %%
#получение корпуса из Wikipedia с темой Сетевая модель OSI на Вьетнамском языке 
import wikipedia
language = "vi"
wikipedia.set_lang(language)
result = wikipedia.search("Mô hình OSI")
#print(result)
page = wikipedia.page(result[0])
inputData= page.content

# %%
#множество наконечных слов
pathfile=('VietnameseStopword.txt')
f = open(pathfile, "r",encoding="utf8")
document1=f.read()
f.close()
stopwordDict=document1.split('\n')
setStopWord=set()
for elem in stopwordDict:
    setStopWord.add(elem)

# %%
# -*- coding: utf-8 -*-
"""
Created on Wed Jul 14 00:10:28 2021

@author: Khanh_Virus
"""
#Процесс предобработки вьетнамских текстов спомощью библиотеки underthesea 
import regex as re
from underthesea import word_tokenize
import io
uniChars = "àáảãạâầấẩẫậăằắẳẵặèéẻẽẹêềếểễệđìíỉĩịòóỏõọôồốổỗộơờớởỡợùúủũụưừứửữựỳýỷỹỵÀÁẢÃẠÂẦẤẨẪẬĂẰẮẲẴẶÈÉẺẼẸÊỀẾỂỄỆĐÌÍỈĨỊÒÓỎÕỌÔỒỐỔỖỘƠỜỚỞỠỢÙÚỦŨỤƯỪỨỬỮỰỲÝỶỸỴÂĂĐÔƠƯ"
unsignChars = "aaaaaaaaaaaaaaaaaeeeeeeeeeeediiiiiooooooooooooooooouuuuuuuuuuuyyyyyAAAAAAAAAAAAAAAAAEEEEEEEEEEEDIIIOOOOOOOOOOOOOOOOOOOUUUUUUUUUUUYYYYYAADOOU"
 
def loaddicchar():
    dic = {}
    char1252 = 'à|á|ả|ã|ạ|ầ|ấ|ẩ|ẫ|ậ|ằ|ắ|ẳ|ẵ|ặ|è|é|ẻ|ẽ|ẹ|ề|ế|ể|ễ|ệ|ì|í|ỉ|ĩ|ị|ò|ó|ỏ|õ|ọ|ồ|ố|ổ|ỗ|ộ|ờ|ớ|ở|ỡ|ợ|ù|ú|ủ|ũ|ụ|ừ|ứ|ử|ữ|ự|ỳ|ý|ỷ|ỹ|ỵ|À|Á|Ả|Ã|Ạ|Ầ|Ấ|Ẩ|Ẫ|Ậ|Ằ|Ắ|Ẳ|Ẵ|Ặ|È|É|Ẻ|Ẽ|Ẹ|Ề|Ế|Ể|Ễ|Ệ|Ì|Í|Ỉ|Ĩ|Ị|Ò|Ó|Ỏ|Õ|Ọ|Ồ|Ố|Ổ|Ỗ|Ộ|Ờ|Ớ|Ở|Ỡ|Ợ|Ù|Ú|Ủ|Ũ|Ụ|Ừ|Ứ|Ử|Ữ|Ự|Ỳ|Ý|Ỷ|Ỹ|Ỵ'.split(
        '|')
    charutf8 = "à|á|ả|ã|ạ|ầ|ấ|ẩ|ẫ|ậ|ằ|ắ|ẳ|ẵ|ặ|è|é|ẻ|ẽ|ẹ|ề|ế|ể|ễ|ệ|ì|í|ỉ|ĩ|ị|ò|ó|ỏ|õ|ọ|ồ|ố|ổ|ỗ|ộ|ờ|ớ|ở|ỡ|ợ|ù|ú|ủ|ũ|ụ|ừ|ứ|ử|ữ|ự|ỳ|ý|ỷ|ỹ|ỵ|À|Á|Ả|Ã|Ạ|Ầ|Ấ|Ẩ|Ẫ|Ậ|Ằ|Ắ|Ẳ|Ẵ|Ặ|È|É|Ẻ|Ẽ|Ẹ|Ề|Ế|Ể|Ễ|Ệ|Ì|Í|Ỉ|Ĩ|Ị|Ò|Ó|Ỏ|Õ|Ọ|Ồ|Ố|Ổ|Ỗ|Ộ|Ờ|Ớ|Ở|Ỡ|Ợ|Ù|Ú|Ủ|Ũ|Ụ|Ừ|Ứ|Ử|Ữ|Ự|Ỳ|Ý|Ỷ|Ỹ|Ỵ".split(
        '|')
    for i in range(len(char1252)):
        dic[char1252[i]] = charutf8[i]
    return dic
dicchar = loaddicchar()

#Переобразование Unicode чащее использования
# Hàm chuyển Unicode dựng sẵn về Unicde tổ hợp (phổ biến hơn)
def convert_unicode(txt):
    return re.sub(
        r'à|á|ả|ã|ạ|ầ|ấ|ẩ|ẫ|ậ|ằ|ắ|ẳ|ẵ|ặ|è|é|ẻ|ẽ|ẹ|ề|ế|ể|ễ|ệ|ì|í|ỉ|ĩ|ị|ò|ó|ỏ|õ|ọ|ồ|ố|ổ|ỗ|ộ|ờ|ớ|ở|ỡ|ợ|ù|ú|ủ|ũ|ụ|ừ|ứ|ử|ữ|ự|ỳ|ý|ỷ|ỹ|ỵ|À|Á|Ả|Ã|Ạ|Ầ|Ấ|Ẩ|Ẫ|Ậ|Ằ|Ắ|Ẳ|Ẵ|Ặ|È|É|Ẻ|Ẽ|Ẹ|Ề|Ế|Ể|Ễ|Ệ|Ì|Í|Ỉ|Ĩ|Ị|Ò|Ó|Ỏ|Õ|Ọ|Ồ|Ố|Ổ|Ỗ|Ộ|Ờ|Ớ|Ở|Ỡ|Ợ|Ù|Ú|Ủ|Ũ|Ụ|Ừ|Ứ|Ử|Ữ|Ự|Ỳ|Ý|Ỷ|Ỹ|Ỵ',
        lambda x: dicchar[x.group()], txt)

bang_nguyen_am = [['a', 'à', 'á', 'ả', 'ã', 'ạ', 'a'],
                  ['ă', 'ằ', 'ắ', 'ẳ', 'ẵ', 'ặ', 'aw'],
                  ['â', 'ầ', 'ấ', 'ẩ', 'ẫ', 'ậ', 'aa'],
                  ['e', 'è', 'é', 'ẻ', 'ẽ', 'ẹ', 'e'],
                  ['ê', 'ề', 'ế', 'ể', 'ễ', 'ệ', 'ee'],
                  ['i', 'ì', 'í', 'ỉ', 'ĩ', 'ị', 'i'],
                  ['o', 'ò', 'ó', 'ỏ', 'õ', 'ọ', 'o'],
                  ['ô', 'ồ', 'ố', 'ổ', 'ỗ', 'ộ', 'oo'],
                  ['ơ', 'ờ', 'ớ', 'ở', 'ỡ', 'ợ', 'ow'],
                  ['u', 'ù', 'ú', 'ủ', 'ũ', 'ụ', 'u'],
                  ['ư', 'ừ', 'ứ', 'ử', 'ữ', 'ự', 'uw'],
                  ['y', 'ỳ', 'ý', 'ỷ', 'ỹ', 'ỵ', 'y']]
bang_ky_tu_dau = ['', 'f', 's', 'r', 'x', 'j']

nguyen_am_to_ids = {}

for i in range(len(bang_nguyen_am)):
    for j in range(len(bang_nguyen_am[i]) - 1):
        nguyen_am_to_ids[bang_nguyen_am[i][j]] = (i, j)

def chuan_hoa_dau_tu_tieng_viet(word):
    if not is_valid_vietnam_word(word):
        return word
    chars = list(word)
    dau_cau = 0
    nguyen_am_index = []
    qu_or_gi = False
    for index, char in enumerate(chars):
        x, y = nguyen_am_to_ids.get(char, (-1, -1))
        if x == -1:
            continue
        elif x == 9:  # check qu
            if index != 0 and chars[index - 1] == 'q':
                chars[index] = 'u'
                qu_or_gi = True
        elif x == 5:  # check gi
            if index != 0 and chars[index - 1] == 'g':
                chars[index] = 'i'
                qu_or_gi = True
        if y != 0:
            dau_cau = y
            chars[index] = bang_nguyen_am[x][0]
        if not qu_or_gi or index != 1:
            nguyen_am_index.append(index)
    if len(nguyen_am_index) < 2:
        if qu_or_gi:
            if len(chars) == 2:
                x, y = nguyen_am_to_ids.get(chars[1])
                chars[1] = bang_nguyen_am[x][dau_cau]
            else:
                x, y = nguyen_am_to_ids.get(chars[2], (-1, -1))
                if x != -1:
                    chars[2] = bang_nguyen_am[x][dau_cau]
                else:
                    chars[1] = bang_nguyen_am[5][dau_cau] if chars[1] == 'i' else bang_nguyen_am[9][dau_cau]
            return ''.join(chars)
        return word

    for index in nguyen_am_index:
        x, y = nguyen_am_to_ids[chars[index]]
        if x == 4 or x == 8:  # ê, ơ
            chars[index] = bang_nguyen_am[x][dau_cau]
            return ''.join(chars)

    if len(nguyen_am_index) == 2:
        if nguyen_am_index[-1] == len(chars) - 1:
            x, y = nguyen_am_to_ids[chars[nguyen_am_index[0]]]
            chars[nguyen_am_index[0]] = bang_nguyen_am[x][dau_cau]
        else:
            x, y = nguyen_am_to_ids[chars[nguyen_am_index[1]]]
            chars[nguyen_am_index[1]] = bang_nguyen_am[x][dau_cau]
    else:
        x, y = nguyen_am_to_ids[chars[nguyen_am_index[1]]]
        chars[nguyen_am_index[1]] = bang_nguyen_am[x][dau_cau]
    return ''.join(chars)


def is_valid_vietnam_word(word):
    chars = list(word)
    nguyen_am_index = -1
    for index, char in enumerate(chars):
        x, y = nguyen_am_to_ids.get(char, (-1, -1))
        if x != -1:
            if nguyen_am_index == -1:
                nguyen_am_index = index
            else:
                if index - nguyen_am_index != 1:
                    return False
                nguyen_am_index = index
    return True

#Стандартизировать вьетнамскую пунктуацию
def chuan_hoa_dau_cau_tieng_viet(sentence):
    """
        Chuyển câu tiếng việt về chuẩn gõ dấu kiểu cũ.
        :param sentence:
        :return:
        """
    sentence = sentence.lower()
    words = sentence.split()
    for index, word in enumerate(words):
        cw = re.sub(r'(^\p{P}*)([p{L}.]*\p{L}+)(\p{P}*$)', r'\1/\2/\3', word).split('/')
        # print(cw)
        if len(cw) == 3:
            cw[1] = chuan_hoa_dau_tu_tieng_viet(cw[1])
        words[index] = ''.join(cw)
    return ' '.join(words)

def remove_html(txt):
    return re.sub(r'<[^>]*>', '', txt)

def remove_stop_words(corpus):
    results = []
    for text in corpus:
        tmp = text.split(' ')
        for stop_word in stopwordDict:
            if stop_word in tmp:
                tmp.remove(stop_word)
        results.append(" ".join(tmp))
    return results

def text_preprocess(document):
    # удаление html code
    document = remove_html(document)
    # стандартизиция unicode
    document = convert_unicode(document)
    # стандартизиция вьетнамской пунктуации
    document = chuan_hoa_dau_cau_tieng_viet(document)
    # извлечение слов
    document = word_tokenize(document, format="text")
    # переобразование lower
    document = document.lower()
    # удаление не нужные символы 
    document = re.sub(r'[^\s\wáàảãạăắằẳẵặâấầẩẫậéèẻẽẹêếềểễệóòỏõọôốồổỗộơớờởỡợíìỉĩịúùủũụưứừửữựýỳỷỹỵđ_]',' ',document)
    # удаление пустой символ
    document = re.sub(r'\s+', ' ', document).strip()
    #удаление цифры
    document=re.sub(r'\d+', ' ', document)
    return document
document = """
"""
document = text_preprocess(document)

# %%
inputData=text_preprocess(inputData).strip()
inputData
# Out:
# 'mô_hình osi open systems interconnection reference model viết ngắn là osi model hoặc osi reference model tạm dịch là mô_hình tham_chiếu kết_nối các hệ_thống mở là một thiết_kế dựa vào nguyên_lý tầng cấp lý_giải một_cách trừu_tượng kỹ_thuật kết_nối truyền_thông giữa các máy_tính và thiết_kế giao thức mạng giữa chúng mô_hình này được phát_triển thành một phần trong kế_hoạch kết_nối các hệ_thống mở open systems interconnection do iso và iut t khởi_xướng nó còn được gọi_là mô_hình bảy tầng của osi mục_đích mô_hình osi sắp_xếp một giao_thức với chức_năng của nó vào một hoặc một nhóm các lớp tương_ứng mỗi một tầng cấp có một đặc_tính là nó chỉ sử_dụng chức_năng của tầng dưới nó đồng_thời chỉ cho_phép tầng trên sử_dụng các chức_năng của mình một hệ_thống cài_đặt các giao_thức bao_gồm một chuỗi các tầng nói trên được gọi_là chồng giao_thức protocol stack chồng giao_thức có_thể được cài_đặt trên phần_cứng hoặc phần_mềm hoặc là tổ_hợp của cả hai thông_thường thì chỉ có những tầng thấp hơn là 
# ...

# %%
setDict=inputData.split()
setDict=remove_stop_words(setDict)
setDict = [ele for ele in setDict if ele.strip()]
trainSet=dict.fromkeys(setDict, 0)
for word in setDict:
    trainSet[word]+=1
trainSet
# Out:
# {'mô_hình': 22,
#  'osi': 23,
#  'open': 4,
#  'systems': 3,
#  'interconnection': 3,
#  'reference': 3,
#  'model': 9,
#  'viết': 2,
#  'ngắn': 3,
#  'tạm': 1,
#  'dịch': 3,
#  'tham_chiếu': 3,
#  'kết_nối': 8,
#  'hệ_thống': 7,
#  'thiết_kế': 4,
#  'dựa': 1,
#  'nguyên_lý': 1,
#  'tầng': 94,
#  'lý_giải': 1,
#  'một_cách': 5,
#  'trừu_tượng': 1,
#  'kỹ_thuật': 3,
#  'truyền_thông': 7,
#  'máy_tính': 5,
#  'giao': 24,
#  'thức': 17,
#  'mạng': 33,
#  'phát_triển': 1,
#  'thành': 3,
#  'kế_hoạch': 1,
#  'iso': 7,
#  'iut': 1,
#  't': 1,
#  'khởi_xướng': 1,
#  'gọi_là': 5,
#  'bảy': 4,
#  'mục_đích': 2,
#  'sắp_xếp': 2,
#  'giao_thức': 10,
#  'chức_năng': 11,
#  'lớp': 2,
#  'tương_ứng': 2,
#  'đặc_tính': 1,
#  'sử_dụng': 6,
#  'đồng_thời': 2,
#  'cho_phép': 4,
#  'cài_đặt': 6,
#  'bao_gồm': 6,
#  'chuỗi': 2,
#  'chồng': 5,
#  'protocol': 2,
#  'stack': 1,
#  'có_thể': 5,
#  'phần_cứng': 2,
#  'phần_mềm': 2,
#  'tổ_hợp': 1,
#  'hai': 2,
#  'thông_thường': 2,
#  'ngành': 1,
# ...

# %%
sorted_trainSet = {}
sorted_keys = sorted(trainSet, key=trainSet.get,reverse=True)
for w in sorted_keys:
    sorted_trainSet[w] = trainSet[w]
print(sorted_trainSet)
# Out:
# {'tầng': 94, 'mạng': 33, 'giao': 24, 'osi': 23, 'mô_hình': 22, 'dữ_liệu': 21, 'thức': 17, 'chức_năng': 11, 'truyền': 11, 'ứng_dụng': 11, 'giao_thức': 10, 'model': 9, 'giao_diện': 9, 'tiêu_chuẩn': 9, 'vật_lý': 9, 'layer': 9, 'thiết_bị': 9, 'liên_kết': 9, 'kết_nối': 8, 'đặc_tả': 8, 'cung_cấp': 8, 'ví_dụ': 8, 'network': 8, 'hệ_thống': 7, 'truyền_thông': 7, 'iso': 7, 'hoạt_động': 7, 'data': 7, 'vận': 7, 'sử_dụng': 6, 'cài_đặt': 6, 'bao_gồm': 6, 'tcpip': 6, 'dịch_vụ': 6, 'địa_chỉ': 6, 'một_cách': 5, 'máy_tính': 5, 'gọi_là': 5, 'chồng': 5, 'có_thể': 5, 'link': 5, 'gói': 5, 'phiên': 5, 'open': 4, 'thiết_kế': 4, 'bảy': 4, 'cho_phép': 4, 'for': 4, 'đường': 4, 'phương_tiện': 4, 'quy_trình': 4, 'ieee': 4, 'chuyển_mạch': 4, 'systems': 3, 'interconnection': 3, 'reference': 3, 'ngắn': 3, 'dịch': 3, 'tham_chiếu': 3, 'kỹ_thuật': 3, 'thành': 3, 'thực_thi': 3, 'thành_phần': 3, 'độ': 3, 'tin_cậy': 3, 'lưu_trữ': 3, 'thực_hiện': 3, 'thiết_lập': 3, 'điều_khiển': 3, 'ethernet': 3, 'mạng_cục_bộ': 3, 'điển_h
# ...

# %%
import pandas as pd
pd.DataFrame([sorted_trainSet]).iloc[0,0:50]
# Out:
# tầng            94
# mạng            33
# giao            24
# osi             23
# mô_hình         22
# dữ_liệu         21
# thức            17
# chức_năng       11
# truyền          11
# ứng_dụng        11
# giao_thức       10
# model            9
# giao_diện        9
# tiêu_chuẩn       9
# vật_lý           9
# layer            9
# thiết_bị         9
# liên_kết         9
# kết_nối          8
# đặc_tả           8
# cung_cấp         8
# ví_dụ            8
# network          8
# hệ_thống         7
# truyền_thông     7
# iso              7
# hoạt_động        7
# data             7
# vận              7
# sử_dụng          6
# cài_đặt          6
# bao_gồm          6
# tcpip            6
# dịch_vụ          6
# địa_chỉ          6
# một_cách         5
# máy_tính         5
# gọi_là           5
# chồng            5
# có_thể           5
# link             5
# gói              5
# phiên            5
# open             4
# thiết_kế         4
# bảy              4
# cho_phép         4
# ...

# %%
result_test = wikipedia.search("Lịch sử Việt Nam")
#print(result)
page_test = wikipedia.page(result_test[0])
inputTest= page_test.content
inputB=text_preprocess(inputTest).strip()
inputB
# Out:
# 'lịch_sử việt nam nếu tính từ lúc có_mặt con_người sinh_sống thì đã có hàng vạn năm trước công_nguyên còn tính từ khi cơ_cấu nhà_nước được hình_thành thì mới khoảng từ năm   năm trước công_nguyên các nhà khảo_cổ đã tìm thấy các di_tích chứng_minh loài_người đã từng sống tại việt nam từ thời_đại đồ_đá cũ thuộc nền văn_hóa tràng_an ngườm sơn_vi và soi nhụ vào thời_kỳ đồ_đá mới nền văn_hóa_hòa_bình bắc_sơn tại vùng này đã phát_triển về chăn_nuôi và nông_nghiệp đặc_biệt là kỹ_thuật trồng lúa_nước những người việt tiền_sử trên vùng châu_thổ sông hồng văn_minh sông hồng và sông_mã này đã khai_hóa đất để trồng_trọt tạo ra một hệ_thống đê_điều để chế_ngự nước lụt của các sông đào kênh để phục_vụ cho việc trồng lúa và đã tạo nên nền văn_minh lúa_nước và văn_hóa làng_xã truyền_thuyết kể rằng từ năm   tcn nhà_nước xích quỷ của người việt đã hình_thành cùng thời với truyền_thuyết về tam_hoàng_ngũ đế tại trung_quốc tuy_nhiên đây chỉ là truyền_thuyết dân_gian các nghiên_cứu khảo_cổ hiện chưa tìm đ
# ...

# %%
setA=set()
setB=set()
setC=set()
for elem in inputData.split():
    setA.add(elem)
for ele in inputB.split():
    setB.add(ele)
setC=setA-setB-setStopWord
setC
# Out:
# {'_cáp',
#  'access',
#  'adapter',
#  'adccp',
#  'address',
#  'addressing',
#  'adjournment',
#  'all',
#  'aloha',
#  'anytime',
#  'application',
#  'aps',
#  'architecture',
#  'area',
#  'arpanet',
#  'ascii',
#  'away',
#  'bell',
#  'berkeley',
#  'biến_đổi',
#  'biểu_diễn',
#  'bond',
#  'burrito',
#  'bus',
#  'bánh',
#  'bên_cạnh',
#  'bình_luận',
#  'bảng',
#  'bảo_mật',
#  'bảy',
#  'bất_kể',
#  'bố_trí',
#  'cable',
#  'card',
#  'channel',
#  'checkpointing',
#  'chi_tiết',
#  'chia_sẻ',
#  'cho_dù',
#  'chuyên_dụng',
#  'chuyển_mạch',
#  'chuyển_tải',
#  'chuyển_đổi',
#  'chuỗi',
#  'chú_ý',
#  'chăng_nữa',
#  'chương_trình',
#  'chất_lượng',
#  'chẳng_hạn',
#  'chồng',
#  'chức_năng',
#  'close',
#  'comments',
#  'communication',
#  'communications',
#  'connection',
#  'contention',
#  'control',
#  'converter',
#  'cybertelecom',
#  'cài_đặt',
#  'câu_chuyện',
#  'công_nghệ_thông_tin',
#  'công_trình',
#  'căn_bản',
#  'cấu_trúc',
#  'cắm',
#  'cợt',
# ...

# %%
testDict=dict.fromkeys(setC,0)
for word in inputData.split():
    if (word in setC):
        testDict[word]+=1
testDict
# Out:
# {'bình_luận': 1,
#  'close': 1,
#  'cho_dù': 2,
#  'on': 1,
#  'câu_chuyện': 1,
#  'tường_trình': 1,
#  'hoàn_thành': 2,
#  'ascii': 1,
#  'ứng_dụng': 11,
#  'port': 1,
#  'llc': 1,
#  'wayback': 2,
#  'model': 9,
#  'graceful': 1,
#  'thức': 17,
#  'logic': 1,
#  'cấu_trúc': 2,
#  'internet': 1,
#  'not': 2,
#  'quy_trình': 4,
#  'throw': 1,
#  'nút': 2,
#  'biểu_diễn': 1,
#  'dấu': 1,
#  'thông_điệp': 2,
#  'router': 1,
#  'trạng_thái': 1,
#  'area': 1,
#  'chăng_nữa': 1,
#  'open': 4,
#  'quốc_phòng': 1,
#  'aloha': 1,
#  'fddi': 2,
#  'hiệu_quả': 2,
#  'tin_cậy': 3,
#  'bánh': 1,
#  'bất_kể': 1,
#  'thấu_đáo': 1,
#  'smtp': 1,
#  'iso': 7,
#  'chồng': 5,
#  'dick': 1,
#  'v': 1,
#  'chuyển_đổi': 2,
#  'phục_hồi': 2,
#  'thông_dụng': 1,
#  'networks': 1,
#  'processing': 1,
#  'termination': 1,
#  'vol': 1,
#  'bảng': 1,
#  'ndis': 1,
#  'lewis': 1,
#  'nghĩa': 2,
#  'osi': 23,
#  'soạn_thảo': 1,
#  'token': 1,
#  'hợp_lý': 1,
#  'trì_hoãn': 1,
#  'tương_tác': 1,
# ...

# %%
sorted_testSet = {}
sorted_keys = sorted(testDict, key=testDict.get,reverse=True)
for w in sorted_keys:
    sorted_testSet[w] = testDict[w]
print(sorted_testSet)
# Out:
# {'tầng': 94, 'osi': 23, 'dữ_liệu': 21, 'thức': 17, 'ứng_dụng': 11, 'chức_năng': 11, 'giao_thức': 10, 'model': 9, 'thiết_bị': 9, 'giao_diện': 9, 'vật_lý': 9, 'layer': 9, 'kết_nối': 8, 'ví_dụ': 8, 'đặc_tả': 8, 'network': 8, 'iso': 7, 'truyền_thông': 7, 'vận': 7, 'data': 7, 'tcpip': 6, 'địa_chỉ': 6, 'cài_đặt': 6, 'chồng': 5, 'máy_tính': 5, 'link': 5, 'gói': 5, 'quy_trình': 4, 'open': 4, 'ieee': 4, 'for': 4, 'chuyển_mạch': 4, 'thiết_kế': 4, 'phương_tiện': 4, 'bảy': 4, 'tin_cậy': 3, 'tham_chiếu': 3, 'tcp': 3, 'độ': 3, 'transport': 3, 'systems': 3, 'nhan_đề': 3, 'interconnection': 3, 'trình': 3, 'ethernet': 3, 'interface': 3, 'lưu_trữ': 3, 'mạng_cục_bộ': 3, 'điển_hình': 3, 'thành_phần': 3, 'reference': 3, 'cho_dù': 2, 'hoàn_thành': 2, 'wayback': 2, 'cấu_trúc': 2, 'not': 2, 'nút': 2, 'thông_điệp': 2, 'fddi': 2, 'hiệu_quả': 2, 'chuyển_đổi': 2, 'phục_hồi': 2, 'nghĩa': 2, 'scheme': 2, 'phần_mềm': 2, 'ám_chỉ': 2, 'presentation': 2, 'đơn': 2, 'arpanet': 2, 'connection': 2, 'machine': 2, 'aps': 2
# ...

# %%
import pandas as pd
pd.DataFrame([sorted_testSet]).iloc[0,0:50]
# Out:
# tầng               94
# osi                23
# dữ_liệu            21
# thức               17
# ứng_dụng           11
# chức_năng          11
# giao_thức          10
# model               9
# thiết_bị            9
# giao_diện           9
# vật_lý              9
# layer               9
# kết_nối             8
# ví_dụ               8
# đặc_tả              8
# network             8
# iso                 7
# truyền_thông        7
# vận                 7
# data                7
# tcpip               6
# địa_chỉ             6
# cài_đặt             6
# chồng               5
# máy_tính            5
# link                5
# gói                 5
# quy_trình           4
# open                4
# ieee                4
# for                 4
# chuyển_mạch         4
# thiết_kế            4
# phương_tiện         4
# bảy                 4
# tin_cậy             3
# tham_chiếu          3
# tcp                 3
# độ                  3
# transport           3
# systems             3
# ...
